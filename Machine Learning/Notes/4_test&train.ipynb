# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/carprices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
x=df[['Mileage','Age(yrs)']]
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y=df['Sell Price($)']

# %%
plt.xlabel('mileage')
plt.ylabel('sell price')
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
plt.xlabel('Age(yrs)')
plt.ylabel('sell price')
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_train
# Out:
#     Mileage  Age(yrs)
# 19    52000         5
# 2     57000         5
# 8     91000         8
# 6     52000         5
# 3     22500         2
# 15    25400         3
# 10    83000         7
# 4     46000         4
# 7     72000         6
# 9     67000         6
# 14    82450         7
# 11    79000         7
# 17    69000         5
# 5     59000         5

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([34249.92054222, 25686.04507379, 22238.66633699, 15928.10016159,
#        25052.43031324, 36445.4607829 ])

# %%
y_test
# Out:
# 1     34000
# 12    26000
# 0     18000
# 18    12800
# 13    27500
# 16    35500
# Name: Sell Price($), dtype: int64

# %%
reg.score(x_test,y_test)
# Out:
# 0.9116682407160392

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)
x_train
# Out:
#     Mileage  Age(yrs)
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6
